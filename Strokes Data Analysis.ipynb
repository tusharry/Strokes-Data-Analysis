# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\ADMIN\Desktop\CODES\healthcare-dataset-stroke-data.csv')
data
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
data.shape
# Out:
# (5110, 12)

# %%
data.drop(['id'], axis = 'columns', inplace = True)

# %%
data
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1     Female  61.0             0              0          Yes  Self-employed
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5105  Female  80.0             1              0          Yes        Private
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
# ...

# %%
data.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
data['stroke'].value_counts()
# Out:
# 0    4861
# 1     249
# Name: stroke, dtype: int64

# %%
data.describe(include = 'all')
# Out:
#         gender          age  hypertension  heart_disease ever_married  \
# count     5110  5110.000000   5110.000000    5110.000000         5110
# unique       3          NaN           NaN            NaN            2
# top     Female          NaN           NaN            NaN          Yes
# freq      2994          NaN           NaN            NaN         3353
# mean       NaN    43.226614      0.097456       0.054012          NaN
# std        NaN    22.612647      0.296607       0.226063          NaN
# min        NaN     0.080000      0.000000       0.000000          NaN
# 25%        NaN    25.000000      0.000000       0.000000          NaN
# 50%        NaN    45.000000      0.000000       0.000000          NaN
# 75%        NaN    61.000000      0.000000       0.000000          NaN
# max        NaN    82.000000      1.000000       1.000000          NaN
#
#        work_type Residence_type  avg_glucose_level          bmi  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             5110 non-null   object
#  1   age                5110 non-null   float64
#  2   hypertension       5110 non-null   int64
#  3   heart_disease      5110 non-null   int64
#  4   ever_married       5110 non-null   object
#  5   work_type          5110 non-null   object
#  6   Residence_type     5110 non-null   object
#  7   avg_glucose_level  5110 non-null   float64
#  8   bmi                4909 non-null   float64
#  9   smoking_status     5110 non-null   object
#  10  stroke             5110 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 439.3+ KB

# %%
plt.figure(figsize = (5, 5))
plt.pie(data['gender'].value_counts(), labels = data['gender'].value_counts().keys(), autopct = '%0.1f%%', startangle = 90)
plt.show()

plt.figure(figsize = (5, 5))
plt.pie(data['Residence_type'].value_counts(), labels = data['Residence_type'].value_counts().keys(), autopct = '%0.1f%%', startangle = 90)
plt.show()

plt.figure(figsize = (5, 5))
plt.pie(data['work_type'].value_counts(), labels = data['work_type'].value_counts().keys(), autopct = '%0.1f%%', startangle = 90)
plt.show()

# %%
data['gender'].value_counts()
# Out:
# Female    2994
# Male      2115
# Other        1
# Name: gender, dtype: int64

# %%
data.fillna(np.mean(data['bmi']), inplace = True)

# %%
data.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
numerical_values = data[['age', 'bmi', 'avg_glucose_level']]
categorical_values = data[['gender', 'hypertension', 'heart_disease', 'ever_married', 'work_type', 'Residence_type', 'smoking_status', 'stroke']]

# %%
plt.figure(figsize = (8, 6))
sns.kdeplot(data = numerical_values, shade = True)
plt.grid()
plt.title('Strokes according to AGE, BMI, AVG_GLUCOSE_LEVEL')
# Out:
# Text(0.5, 1.0, 'Strokes according to AGE, BMI, AVG_GLUCOSE_LEVEL')

# %%
plt.figure(figsize = (8, 6))
sns.kdeplot(x = data.loc[data['stroke'] == 1]['age'], shade = True, label = 'Stroke')
sns.kdeplot(x = data.loc[data['stroke'] == 0]['age'], shade = True, label = 'No Stroke')
plt.legend(loc = 'upper left')
plt.grid()
plt.title('Strokes according to AGE')

plt.figure(figsize = (8, 6))
sns.kdeplot(data['bmi'], shade = True)
sns.kdeplot(x = data.loc[data['stroke'] == 1]['bmi'], shade = True, label = 'Stroke')
sns.kdeplot(x = data.loc[data['stroke'] == 0]['bmi'], shade = True, label = 'No Stroke')
plt.legend(loc = 'best')
plt.grid()
plt.title('Strokes according to BMI')

plt.figure(figsize = (8, 6))
sns.kdeplot(x = data.loc[data['stroke'] ==1]['avg_glucose_level'], shade = True, label = 'Stroke')
sns.kdeplot(x = data.loc[data['stroke'] ==0]['avg_glucose_level'], shade = True, label = 'No Stroke')
plt.legend(loc = 'best')
plt.grid()
plt.title('Strokes according to AVG_GLUCOSE_LEVEL')
# Out:
# Text(0.5, 1.0, 'Strokes according to AVG_GLUCOSE_LEVEL')

# %%
plt.figure(figsize = (12, 7))
sns.scatterplot(x = data['age'], y = data['bmi'], hue = categorical_values['stroke'], palette="OrRd")
plt.legend(loc = 'best')
plt.grid()
plt.title('BMI -> AGE')

plt.figure(figsize = (12, 7))
sns.scatterplot(x = data['age'], y = data['avg_glucose_level'], hue = categorical_values['stroke'], palette="OrRd")
plt.legend(loc = 'best')
plt.grid()
plt.title('AVG_GLUCOSE_LEVEL -> AGE')

plt.figure(figsize = (12, 7))
sns.scatterplot(x = data['bmi'], y = data['avg_glucose_level'],  hue = categorical_values['stroke'], palette="OrRd")
plt.legend(loc = 'best')
plt.grid()
plt.title('AVG_GLUCOSE_LEVEL -> BMI')
# Out:
# Text(0.5, 1.0, 'AVG_GLUCOSE_LEVEL -> BMI')

# %%
sns.pairplot(data = data, hue = 'stroke')

# %%
plt.figure(figsize= (7, 7))
sns.heatmap(data.corr(), cmap= 'Blues', annot= True, linewidths= 1, square = True)
plt.title('Correlation Matrix', fontsize= 16)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
sns.countplot(x = 'gender', data = data)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.countplot(x = 'hypertension', data = data)
# Out:
# <AxesSubplot:xlabel='hypertension', ylabel='count'>

# %%
#('gender', 'hypertension', 'heart_disease', 'ever_married', 'work_type', 'Residence_type', 'smoking_status', 'stroke')
sns.countplot(x = 'heart_disease', data = data)
# Out:
# <AxesSubplot:xlabel='heart_disease', ylabel='count'>

# %%
sns.countplot(x = 'ever_married', data = data)
# Out:
# <AxesSubplot:xlabel='ever_married', ylabel='count'>

# %%
sns.countplot(x = 'work_type', data = data)
# Out:
# <AxesSubplot:xlabel='work_type', ylabel='count'>

# %%
sns.countplot(x = 'Residence_type', data = data)
# Out:
# <AxesSubplot:xlabel='Residence_type', ylabel='count'>

# %%
sns.countplot(x = 'smoking_status', data = data)
# Out:
# <AxesSubplot:xlabel='smoking_status', ylabel='count'>

# %%
sns.countplot(x = 'stroke', data = data)
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='count'>
